# %% [markdown]
# Example from https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd

# %%
rng = np.random.RandomState(1)
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T

# %%
df = pd.DataFrame(X)
df
# Out:
#             0         1
# 0   -0.625302 -0.170064
# 1    0.960695  0.590901
# 2   -0.598543 -0.402593
# 3   -2.228059 -0.532577
# 4   -0.461430 -0.498867
# ..        ...       ...
# 195  0.838409  0.278380
# 196  0.312708 -0.010600
# 197  1.955876  0.638224
# 198 -1.108304 -0.395054
# 199  0.398647  0.023187
#
# [200 rows x 2 columns]

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal');

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
print(pca.components_)
# Out:
# [[-0.94446029 -0.32862557]]

# %%
print(pca.components_)
# Out:
# [[-0.94446029 -0.32862557]
#  [-0.32862557  0.94446029]]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.97634101 0.02365899]

# %%
print(sum(pca.explained_variance_ratio_))
# Out:
# 0.9999999999999999
